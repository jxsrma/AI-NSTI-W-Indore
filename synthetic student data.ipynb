# %% [markdown]
# # Student Data Analysis

# %% [markdown]
# ## 🔧 Preprocessing
#  - Identify and impute missing values for continuous and categorical features.
#  - Encode gender and other categorical fields using Label Encoding or One-Hot Encoding.
#  - Normalize numerical features using StandardScaler.
#  - Remove outliers in exam_stress_level and part_time_work_hours using Z-score.
#  - Drop duplicate records if present.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('synthetic_student_health_data.csv')
df
# Out:
#      student_id  age      gender  sleep_quality  meal_quality  \
# 0          1001   24        Male            6.1           6.4
# 1          1002   21      Female            5.8           5.5
# 2          1003   22        Male            7.5           6.4
# 3          1004   24      Female            8.8           7.5
# 4          1005   20        Male            8.3           7.7
# ..          ...  ...         ...            ...           ...
# 495        1496   23        Male            6.5           8.9
# 496        1497   18        Male            7.5           7.7
# 497        1498   21      Female            5.7           5.3
# 498        1499   19  Non-binary            7.1           9.2
# 499        1500   23        Male            7.3           6.5
#
#      exercise_frequency  hours_studied  part_time_work_hours  \
# 0                     1            5.6                   7.4
# 1                     2           18.8                   3.1
# ...

# %%
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
df
# Out:
#      student_id  age  gender  sleep_quality  meal_quality  exercise_frequency  \
# 0          1001   24       1            6.1           6.4                   1
# 1          1002   21       0            5.8           5.5                   2
# 2          1003   22       1            7.5           6.4                   5
# 3          1004   24       0            8.8           7.5                   1
# 4          1005   20       1            8.3           7.7                   3
# ..          ...  ...     ...            ...           ...                 ...
# 495        1496   23       1            6.5           8.9                   0
# 496        1497   18       1            7.5           7.7                   2
# 497        1498   21       0            5.7           5.3                   5
# 498        1499   19       2            7.1           9.2                   2
# 499        1500   23       1            7.3           6.5                   3
#
# ...

# %%
# df = df[['age',	'gender',	'sleep_quality',	'meal_quality',	'exercise_frequency',	'hours_studied',	'part_time_work_hours',
#          'mental_health_score',	'exam_stress_level',	'gpa',	'passed_gpa',	'healthy_lifestyle',	'cluster_type']]
df.drop('student_id',inplace=True,axis=1)
df
# Out:
#      age  gender  sleep_quality  meal_quality  exercise_frequency  \
# 0     24       1            6.1           6.4                   1
# 1     21       0            5.8           5.5                   2
# 2     22       1            7.5           6.4                   5
# 3     24       0            8.8           7.5                   1
# 4     20       1            8.3           7.7                   3
# ..   ...     ...            ...           ...                 ...
# 495   23       1            6.5           8.9                   0
# 496   18       1            7.5           7.7                   2
# 497   21       0            5.7           5.3                   5
# 498   19       2            7.1           9.2                   2
# 499   23       1            7.3           6.5                   3
#
#      hours_studied  part_time_work_hours  mental_health_score  \
# 0              5.6                   7.4                 64.6
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df = pd.DataFrame(ss.fit_transform(df), columns=['age',	'gender',	'sleep_quality',	'meal_quality',	'exercise_frequency',	'hours_studied',	'part_time_work_hours',
                                                 'mental_health_score',	'exam_stress_level',	'gpa',	'passed_gpa',	'healthy_lifestyle',	'cluster_type'])
df
# Out:
#           age    gender  sleep_quality  meal_quality  exercise_frequency  \
# 0    1.503600  0.581143      -0.340777      0.170891           -1.158752
# 1    0.022707 -0.940174      -0.530308     -0.294611           -0.587938
# 2    0.516338  0.581143       0.543701      0.170891            1.124503
# 3    1.503600 -0.940174       1.365002      0.739837           -1.158752
# 4   -0.470924  0.581143       1.049117      0.843281           -0.017124
# ..        ...       ...            ...           ...                 ...
# 495  1.009969  0.581143      -0.088069      1.463949           -1.729566
# 496 -1.458186  0.581143       0.543701      0.843281           -0.587938
# 497  0.022707 -0.940174      -0.593485     -0.398055            1.124503
# 498 -0.964555  2.102461       0.290993      1.619117           -0.587938
# 499  1.009969  0.581143       0.417347      0.222613           -0.017124
#
#      hours_studied  part_time_work_hours  mental_health_score  \
# ...

# %%
df.describe()
# Out:
#                 age        gender  sleep_quality  meal_quality  \
# count  5.000000e+02  5.000000e+02   5.000000e+02  5.000000e+02
# mean  -3.197442e-16  4.263256e-17   4.440892e-16 -1.736389e-16
# std    1.001002e+00  1.001002e+00   1.001002e+00  1.001002e+00
# min   -1.458186e+00 -9.401744e-01  -2.741503e+00 -2.622116e+00
# 25%   -9.645551e-01 -9.401744e-01  -6.566618e-01 -6.566670e-01
# 50%    2.270703e-02  5.811434e-01  -2.489174e-02  4.158477e-02
# 75%    1.009969e+00  5.811434e-01   6.700554e-01  7.398365e-01
# max    1.503600e+00  2.102461e+00   2.123127e+00  2.032895e+00
#
#        exercise_frequency  hours_studied  part_time_work_hours  \
# count        5.000000e+02   5.000000e+02          5.000000e+02
# mean         1.350031e-16  -4.263256e-17         -6.394885e-17
# std          1.001002e+00   1.001002e+00          1.001002e+00
# min         -1.729566e+00  -2.963221e+00         -1.493543e+00
# 25%         -5.879382e-01  -7.429373e-01         -7.592056e-01
# ...

# %%
# from scipy.stats import zscore
# zscore(df)

# %%
sns.boxplot(df)
plt.xticks(rotation = 90)
plt.show()

# %%
# for i in df.columns:
#     sns.boxplot(df[i])
#     plt.xticks(rotation = 90)
#     plt.show()

# %% [markdown]
# ## 📊 Exploratory Data Analysis (EDA)
#  - Plot histograms of gpa, mental_health_score, and exam_stress_level.
#  - Analyze the relationship between hours_studied and gpa using a regression plot.
#  - Compare average GPA between students with high and low sleep_quality.
#  - Plot a correlation heatmap for all numeric variables.
#  - Visualize gender distribution with a pie chart.

# %%
for i in ['gpa','mental_health_score','exam_stress_level']:
    sns.histplot(df[i],kde=True)
    plt.xticks(rotation = 90)
    plt.show()

# %%
plt.scatter(df['hours_studied'],df['gpa'])

# %%
highSQ = df[df['sleep_quality']>=0]
lowSQ = df[df['sleep_quality']<0]
plt.scatter(highSQ['sleep_quality'],highSQ['gpa'])
plt.scatter(lowSQ['sleep_quality'],lowSQ['gpa'])

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
genderCount = df[['gender','age']].groupby('gender').count()
plt.pie(genderCount.age,labels=['Male','Female','Non Binary'])
plt.show()

# %% [markdown]
# ## 📈 Regression Models
#  - Build a Linear Regression model to predict gpa using all other numeric features.
#  - Evaluate the model using MAE, RMSE, and R² score.
#  - Visualize predicted vs actual GPA with a scatter plot.
#  - Compare prediction results for mental_health_score using a regression model — which features are more predictive?

# %%
X = df.drop('gpa',axis=1)
X
# Out:
#           age    gender  sleep_quality  meal_quality  exercise_frequency  \
# 0    1.503600  0.581143      -0.340777      0.170891           -1.158752
# 1    0.022707 -0.940174      -0.530308     -0.294611           -0.587938
# 2    0.516338  0.581143       0.543701      0.170891            1.124503
# 3    1.503600 -0.940174       1.365002      0.739837           -1.158752
# 4   -0.470924  0.581143       1.049117      0.843281           -0.017124
# ..        ...       ...            ...           ...                 ...
# 495  1.009969  0.581143      -0.088069      1.463949           -1.729566
# 496 -1.458186  0.581143       0.543701      0.843281           -0.587938
# 497  0.022707 -0.940174      -0.593485     -0.398055            1.124503
# 498 -0.964555  2.102461       0.290993      1.619117           -0.587938
# 499  1.009969  0.581143       0.417347      0.222613           -0.017124
#
#      hours_studied  part_time_work_hours  mental_health_score  \
# ...

# %%
y = df['gpa']
y
# Out:
# 0     -1.583155
# 1      1.040031
# 2      2.039340
# 3      0.190618
# 4     -0.159140
#          ...
# 495   -0.558864
# 496    0.065705
# 497    0.265566
# 498   -0.184123
# 499   -0.983570
# Name: gpa, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
LRModel = LinearRegression()
LRModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LRModel.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,root_mean_squared_error, r2_score

# %%
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("RMSE: ", root_mean_squared_error(y_test, y_pred))
print("R2: ", r2_score(y_test, y_pred)*100)
# Out:
# MAE:  0.36732217442683646
# RMSE:  0.46389446338840695
# R2:  82.27394191559635

# %% [markdown]
# ## 🎯 Classification Models
#  - Train a Logistic Regression model to classify passed_gpa.
#  - Evaluate using precision, recall, accuracy, and F1 score.
#  - Train a Decision Tree Classifier to predict healthy_lifestyle.
#  - Visualize the tree and discuss feature importance.
#  - Use a Random Forest Classifier and compare its F1 score with the Decision Tree.

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop('passed_gpa',axis=1)
y = pd.read_csv('synthetic_student_health_data.csv')['passed_gpa']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 495    0
# 496    0
# 497    1
# 498    0
# 499    0
# Name: passed_gpa, Length: 500, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
LRCModel = LogisticRegression()
LRCModel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LRCModel.predict(x_test)

# %%
X = df.drop('healthy_lifestyle',axis=1)
y = df['healthy_lifestyle'].apply(lambda x: round(x))
y
# Out:
# 0      0
# 1      0
# 2      3
# 3      0
# 4      0
#       ..
# 495    0
# 496    0
# 497    0
# 498    0
# 499    0
# Name: healthy_lifestyle, Length: 500, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTModel = DecisionTreeClassifier()
DTModel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predDT = DTModel.predict(x_test)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(5,5))
plot_tree(DTModel,filled=True)
plt.show()

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
RFCModel = RandomForestClassifier()
RFCModel.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
y_predRF = RFCModel.predict(x_test)

# %%
print("f1_score DT: ", f1_score(y_test, y_predDT,pos_label=3))
print("f1_score RF: ", f1_score(y_test, y_predRF,pos_label=3))
# Out:
# f1_score DT:  1.0
# f1_score RF:  1.0

# %% [markdown]
# ## 🧩 Clustering
#  - Cluster students into 3 groups using KMeans on sleep_quality, exam_stress_level, and mental_health_score.
#  - Reduce dimensionality with t-SNE and visualize clusters with color-coded points.

# %%
features = df[['sleep_quality','exam_stress_level','mental_health_score']]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
reduced_Features = pca.fit_transform(features)
plt.scatter(reduced_Features[:,0],reduced_Features[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
KMModel = KMeans(n_clusters=3)
KMModel.fit(reduced_Features)
# Out:
# KMeans(n_clusters=3)

# %%
df['cluster'] = KMModel.predict(reduced_Features)

# %%
from sklearn.manifold import TSNE

# %%
TSNEModel = TSNE(n_components=2)
visual = TSNEModel.fit_transform(df)
visual = pd.DataFrame(visual,columns=['a','b'])
visual = pd.concat([visual,df['cluster']],axis=1)
visual
for i in sorted(visual['cluster'].unique()):
    data = visual[visual['cluster'] == i]
    plt.scatter(data.a, data.b)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'gender', 'sleep_quality', 'meal_quality', 'exercise_frequency',
#        'hours_studied', 'part_time_work_hours', 'mental_health_score',
#        'exam_stress_level', 'gpa', 'passed_gpa', 'healthy_lifestyle',
#        'cluster_type', 'cluster'],
#       dtype='object')

# %%
for i in sorted(df['cluster'].unique()):
    data = df[df['cluster'] == i]
    plt.scatter(data['sleep_quality'], data['exam_stress_level'])
plt.show()

# %%
for i in sorted(df['cluster'].unique()):
    data = df[df['cluster'] == i]
    plt.scatter(data['sleep_quality'], data['mental_health_score'])
plt.show()

# %%
for i in sorted(df['cluster'].unique()):
    data = df[df['cluster'] == i]
    plt.scatter(data['mental_health_score'], data['exam_stress_level'])
plt.show()

# %% [markdown]
# ## ⚙ Support Vector Machine (SVM)
#  - Use SVM to classify whether a student passed_gpa using all features.
#  - Try both linear and RBF kernels and compare their performance metrics.

# %%
from sklearn.svm import SVC

# %%
X = df.drop('passed_gpa',axis=1)
y = df['passed_gpa'].apply(lambda x: round(x))

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
SVCLModel = SVC(kernel='linear')
SVCLModel.fit(x_train,y_train)
y_predSVL = SVCLModel.predict(x_test)

SVCRModel = SVC(kernel='rbf')
SVCRModel.fit(x_train,y_train)
y_predSVR = SVCRModel.predict(x_test)

# %%
print("F1 Score SVM with Linear: ",f1_score(y_test,y_predSVL)*100)
print("F1 Score SVM with RBF: ",f1_score(y_test,y_predSVR)*100)
# Out:
# F1 Score SVM with Linear:  98.79518072289156
# F1 Score SVM with RBF:  93.97590361445783

# %% [markdown]
# | Column Name            | Description                                                    |
# |-------------------------|----------------------------------------------------------------|
# | student_id              | Unique student identifier                                      |
# | age                     | Student's age                                                  |
# | gender                  | 'Male', 'Female', 'Non-binary'                                 |
# | sleep_quality           | Self-reported sleep quality on a scale of 1–10                 |
# | meal_quality            | Self-reported diet rating (1–10)                               |
# | exercise_frequency      | Days per week of moderate exercise                             |
# | hours_studied           | Average study hours per week                                   |
# | part_time_work_hours    | Weekly hours spent on part-time work                           |
# | mental_health_score     | Composite score (higher = better mental health)                |
# | exam_stress_level       | Stress level before exams (1–10)                               |
# | gpa                     | Final GPA (0.0 to 4.0)                                          |
# | passed_gpa              | 1 if GPA ≥ 2.5, else 0                                          |
# | healthy_lifestyle       | 1 if sleep_quality, meal_quality, and exercise_frequency are all above median |
# | cluster_type            | Pre-labeled cluster from prior segmentation                    |
